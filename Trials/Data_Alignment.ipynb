# %% [markdown]
# Here we will align the extracted data from money control with the stats of yahoo finance

# %%
import yfinance as yf

RelNS = yf.Ticker("Reliance.NS")

data = yf.download('Reliance.NS',period='1y', multi_level_index=False)

data.to_csv('Data/raw/yahoo/Reliance_yahoo.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Matching the dtype of dtype of datetime on both the dataframe

import pandas as pd

Reliance_news = pd.read_csv('Data/processed/Reliance.csv', parse_dates=['news_datetime'])

Reliance_news.dtypes
# Out:
# news_id                                str
# headline                               str
# link                                   str
# source                                 str
# raw_date_text                          str
# news_datetime    datetime64[us, UTC+05:30]
# article_text                       float64
# scraped_at                             str
# scrape_page                        float64
# status                                 str
# dtype: object

# %%
Reliance_yahoo = pd.read_csv('Data/raw/yahoo/Reliance_yahoo.csv', parse_dates=['Date'])

Reliance_yahoo.dtypes
# Out:
# Date      datetime64[us]
# Close            float64
# High             float64
# Low              float64
# Open             float64
# Volume             int64
# dtype: object

# %%
trial = Reliance_news['news_datetime'][1]
type(trial)
# Out:
# str

# %%
import pandas as pd
from datetime import time, timedelta, date

# ======================
# LOAD DATA
# ======================

news_path = r"Data\processed\extracted_news\Reliance.csv"
price_path = r"Data\raw\yahoo\Reliance_yahoo.csv"

news_df = pd.read_csv(news_path)
price_df = pd.read_csv(price_path)


# ======================
# DATETIME PROCESSING
# ======================

news_df["news_datetime"] = pd.to_datetime(news_df["news_datetime"])
price_df["Date"] = pd.to_datetime(price_df["Date"])

# normalize price date
price_df["trade_date"] = price_df["Date"].dt.date

# set index for fast lookup
price_df.set_index("trade_date", inplace=True)

# set of valid trading days
trading_days = set(price_df.index)


# ======================
# MARKET CLOSE TIME
# ======================

market_close = time(15, 30) # time - 15:30


# ======================
# FUNCTION: MAP NEWS → TRADING DAY
# ======================

# will find the price date with the corresponding news date
def get_event_date(news_dt):

    news_date = news_dt.date()
        
    # if news released after market close → shift to next day
    
    if news_dt.time() > market_close:
        print(news_dt.time())
        print(market_close)
        news_date += timedelta(days=1)

    # move forward until valid trading day
    while news_date not in trading_days:
        news_date += timedelta(days=1)

    return news_date


# ======================
# FUNCTION: GET FUTURE PRICE
# ======================

# will give the prices
def get_future_price(date, offset):

    d = date
    count = 0

    while count < offset:
        d += timedelta(days=1)
        if d in trading_days:
            count += 1

    return price_df.loc[d]["Close"]


# ======================
# ALIGNMENT LOOP
# ======================

records = []

count = 0
for _, row in news_df.iterrows():

    news_dt = row["news_datetime"]
    print(count)
    try:
        event_date = get_event_date(news_dt) # getting the price date of yahoo finance
    except ValueError:
        continue
    if event_date not in price_df.index:
        continue

    close_T = price_df.loc[event_date]["Close"]

    # future prices
    close_T1 = get_future_price(event_date, 1)
    close_T3 = get_future_price(event_date, 3)
    close_T5 = get_future_price(event_date, 5)

    # returns
    r1 = (close_T1 - close_T) / close_T
    r3 = (close_T3 - close_T) / close_T
    r5 = (close_T5 - close_T) / close_T

    records.append({
        "news_id": row["news_id"],
        "headline": row["headline"],
        "news_time": news_dt,
        "event_date": event_date,
        "close_T": close_T,
        "ret_1d": r1,
        "ret_3d": r3,
        "ret_5d": r5
    })
    count += 1

# ======================
# FINAL DATAFRAME
# ======================

aligned_df = pd.DataFrame(records)

# 521
# 522
# 523
# 524
# 525
# 526
# 527
# 19:25:00
# 15:30:00
# 528
# 16:27:00
# 15:30:00
# 529
# 530
# 19:44:00
# 15:30:00
# 531
# 532
# 533
# 15:37:00
# 15:30:00
# 534
# 535
# 536
# 537
# 16:49:00
# 15:30:00
# 538
# 539
# 540
# 541
# 542
# 543
# 21:29:00
# 15:30:00
# 544
# 545
# 546
# 547
# 548
# 549
# 550
# 551
# 552
# 18:03:00
# 15:30:00
# 553
# 554
# 555
# 556
# 557
# 23:06:00
# 15:30:00
# 558
# 22:42:00
# 15:30:00
# 559
# 17:12:00
# 15:30:00
# 560
# 561
# 562
# 20:20:00
# 15:30:00
# 563
# 18:28:00
# 15:30:00
# 564
# 15:59:00
# 15:30:00
# 565
# 16:18:00
# 15:30:00
# 566
# 18:26:00
# 15:30:00
# 567
# 568
# 569
# 570
# 20:23:00
# 15:30:00
# 571
# 572
# 573
# 16:43:00
# 15:30:00
# 574
# 575
# 575
# 576
# 577
# 17:13:00
# 15:30:00
# 578
# 578
# 578
# 579
# 580
# 581
# 582
# 20:54:00
# 15:30:00
# 583
# 584
# 585
# 586
# 21:38:00
# 15:30:00
# 587
# 21:31:00
# 15:30:00
# 588
# 589
# 21:40:00
# 15:30:00
# 590
# 16:06:00
# 15:30:00
# 591
# 592
# 593
# 594
# 595
# 596
# 596
# 17:51:00
# 15:30:00
# 597
# 21:55:00
# 15:30:00
# 598
# 22:02:00
# 15:30:00
# 599
# 600
# 20:37:00
# 15:30:00
# 601
# 20:12:00
# 15:30:00
# 602
# 602
# 603
# 604
# 19:44:00
# 15:30:00
# 605
# 606
# 606
# 16:52:00
# 15:30:00
# 607
# 608
# 609
# 610
# 611
# 612
# 612
# 613
# 613
# 614
# 615
# 616
# 617
# 17:41:00
# 15:30:00
# 618
# 18:28:00
# 15:30:00
# 619
# 620
# 621
# 621
# 621
# 621
# 622
# 623
# 623
# 624
# 625
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
# 626
#                                 news_id  \
# 0  fe614aa4-f6a9-4dbb-8913-52e44535ecd9
# 1  9f68a144-0ec7-4d78-a170-9df5bdda6ad2
# 2  5586f194-efc5-4b74-9959-078ea2671879
# 3  c05dbbe6-0e58-4aa1-8cb5-500899a12726
# 4  4bee0c21-2c50-4421-9317-b3d9ed3ea711
#
#                                             headline  \
# 0  Stocks to Watch Today: SBI, Aurobindo Pharma, ...
# 1  Mukesh Ambani credits stable leadership under ...
# 2  ONGC in talks with ExxonMobil for joint bids i...
# 3  Goldman Sachs buys minor stake in Axis Bank, V...
# 4  Buy Reliance Industries; target of Rs 1750: Mo...
#
#                   news_time  event_date      close_T    ret_1d    ret_3d  \
# 0 2026-02-09 02:07:00+05:30  2026-02-09  1461.599976 -0.002121 -0.008689
# 1 2026-02-04 18:17:00+05:30  2026-02-05  1443.400024  0.005127  0.010461
# 2 2026-01-28 18:46:00+05:30  2026-01-29  1391.000000  0.003163  0.033142
# 3 2026-01-27 21:05:00+05:30  2026-01-28  1396.699951 -0.004081 -0.004511
# 4 2026-01-21 12:59:00+05:30  2026-01-21  1404.599976 -0.001495 -0.017158
#
#      ret_5d
# 0 -0.016762
# 1  0.003810
# 2  0.037671
# 3  0.043030
# 4 -0.009682
