# %%
from data_extraction.headlines import headlines_extractor

# %%
base_url = "https://www.moneycontrol.com/news/tags/"

# %%
stock_name = ["reliance-industries", "airtel", "idfcfirstbank"]

current_url = base_url+stock_name[2]+"/news/"
current_url
# Out:
# 'https://www.moneycontrol.com/news/tags/idfcfirstbank/news/'

# %%
list_idfc = headlines_extractor(current_url)
# Out:
# Scraping page 1: https://www.moneycontrol.com/news/tags/idfcfirstbank/news//
# Stopping — bad response

# %%
from data_extraction.headlines import headlines_extractor_playwright_asyncio

list_airtel_pw = await headlines_extractor_playwright_asyncio(current_url)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 from data_extraction.headlines import headlines_extractor_playwright_asyncio
# ----> 3 list_airtel_pw = await headlines_extractor_playwright_asyncio(current_url)
#
# File c:\Users\aayus\Dev\Stocks Senti\data_extraction\headlines.py:151, in headlines_extractor_playwright_asyncio(base_url)
#     148 seen_links = set()
#     149 page_no = 1
# --> 151 async with async_playwright() as p:
#     153     browser = await p.chromium.launch(headless=True)
#     154     page = await browser.new_page()
#
# File c:\Users\aayus\Dev\Stocks Senti\MyEnv\Lib\site-packages\playwright\async_api\_context_manager.py:46, in PlaywrightContextManager.__aenter__(self)
#      44 if not playwright_future.done():
#      45     playwright_future.cancel()
# ---> 46 playwright = AsyncPlaywright(next(iter(done)).result())
# ...

# %%
len(list_idfc)
# Out:
# 0
